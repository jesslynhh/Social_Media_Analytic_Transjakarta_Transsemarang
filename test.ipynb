# %%
import os
import pandas as pd

# %%
cleaned_tj = pd.read_csv("Data/Cleaned_TJ_new.csv")
cleaned_ts = pd.read_csv("Data/Cleaned_TS_new.csv")

# %%
cleaned_tj['created_at'].value_counts()
# Out:
# created_at
# Fri Jun 21 11:50:28 +0000 2024    1
# Wed Jun 12 11:11:38 +0000 2024    1
# Wed Jun 12 12:21:33 +0000 2024    1
# Wed Jun 12 12:19:46 +0000 2024    1
# Wed Jun 12 12:00:45 +0000 2024    1
#                                  ..
# Mon Jun 17 13:18:07 +0000 2024    1
# Mon Jun 17 13:24:14 +0000 2024    1
# Mon Jun 17 15:05:04 +0000 2024    1
# Mon Jun 17 15:09:58 +0000 2024    1
# Fri Jun 07 12:19:43 +0000 2024    1
# Name: count, Length: 574, dtype: int64

# %%
cleaned_tj['username'].value_counts()
# Out:
# username
# sweetlullaby90    4
# KangMaman204      4
# euiShnay          4
# uriminhyunie      3
# JeaKelana         3
#                  ..
# apaajadehcape6    1
# kontenindomie     1
# jaaaaaarrrr       1
# sourismoi_        1
# peaceluvngawl     1
# Name: count, Length: 511, dtype: int64

# %%
cleaned_tj[cleaned_tj['username']=='bhismaaa10']
# Out:
#      Unnamed: 0                      created_at  favorite_count  \
# 302         302  Fri Jun 14 12:32:55 +0000 2024               0
#
#                                              full_text               id_str  \
# 302  Ini yg terbiasa naik 7C di hari Jumat dgn tuju...  1801593660586475526
#
#     lang location  quote_count  reply_count  retweet_count    username  \
# 302   in      NaN            0            0              0  bhismaaa10
#
#           keyword
# 302  Transjakarta

# %%
cleaned_ts.sort_values(by='favorite_count', ascending=False)
# Out:
#      Unnamed: 0                      created_at  favorite_count  \
# 292         292  Mon Jan 09 13:23:37 +0000 2023            1976
# 298         298  Thu Jan 05 12:43:38 +0000 2023             114
# 430         431  Sun Aug 14 04:57:50 +0000 2022              77
# 121         121  Wed Dec 27 15:02:50 +0000 2023              66
# 176         176  Tue Sep 19 10:59:54 +0000 2023              59
# ..          ...                             ...             ...
# 177         177  Tue Sep 19 07:30:50 +0000 2023               0
# 175         175  Sat Sep 23 05:03:11 +0000 2023               0
# 174         174  Sat Sep 23 12:01:33 +0000 2023               0
# 173         173  Sun Sep 24 00:24:44 +0000 2023               0
# 252         252  Wed Mar 29 07:16:24 +0000 2023               0
#
#                                              full_text               id_str  \
# 292  Saya baru sadar aplikasi @Transsemarang menges...  1612439956194226177
# ...

# %%
from dateutil import parser

# %%
days=[]

for date in cleaned_tj['created_at']:
    days.append(date[:3])

print(days)
# Out:
# ['Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Fri', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Thu', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'Wed', 'We
# ...

# %%
cleaned_tj['created_day'] = days
cleaned_tj['created_day'].value_counts()
# Out:
# created_day
# Fri    130
# Wed     90
# Thu     75
# Sat     73
# Sun     72
# Mon     71
# Tue     63
# Name: count, dtype: int64

# %%
cleaned_tj.to_csv('./Data/TJ_withDay.csv')
cleaned_ts.to_csv('./Data/TS_withDay.csv')
